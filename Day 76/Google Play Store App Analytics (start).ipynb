# %% [markdown]
# # Introduction
#
# In this notebook, we will do a comprehensive analysis of the Android app market by comparing thousands of apps in the Google Play store.

# %% [markdown]
# # About the Dataset of Google Play Store Apps & Reviews

# %% [markdown]
# **Data Source:** <br>
# App and review data was scraped from the Google Play Store by Lavanya Gupta in 2018. Original files listed [here](
# https://www.kaggle.com/lava18/google-play-store-apps).

# %% [markdown]
# # Import Statements

# %%
import pandas
from plotly import express, graph_objects

# %% [markdown]
# # Notebook Presentation

# %%
# Show numeric output in decimal format e.g., 2.15
pandas.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# # Read the Dataset

# %%
df_apps = pandas.read_csv('apps.csv')

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# **Challenge**: How many rows and columns does `df_apps` have? What are the column names? Look at a random sample of 5 different rows with [.sample()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sample.html).

# %%
df_apps.shape
# Out:
# (10841, 12)

# %%
df_apps.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size_MBs', 'Installs', 'Type',
#        'Price', 'Content_Rating', 'Genres', 'Last_Updated', 'Android_Ver'],
#       dtype='str')

# %%
df_apps.sample(5)
# Out:
#                                                    App   Category  Rating  \
# 3698             Sic Bo (Tai Xiu) - Multiplayer Casino       GAME    4.20
# 4067                         Holy Quran Mehmet Emin Ay  LIFESTYLE     NaN
# 6976  Dungeon Hunter Champions: Epic Online Action RPG     FAMILY    4.20
# 8649                                     Dungeon Quest     FAMILY    4.50
# 4404                               FE CREDIT - TET VUI    FINANCE    4.10
#
#       Reviews  Size_MBs   Installs  Type Price Content_Rating        Genres  \
# 3698      152     16.00     10,000  Free     0           Teen        Casino
# 4067      649     55.00     10,000  Free     0       Everyone     Lifestyle
# 6976    26307     19.00  1,000,000  Free     0           Teen  Role Playing
# 8649   244039     46.00  5,000,000  Free     0   Everyone 10+  Role Playing
# 4404      125     15.00     50,000  Free     0       Everyone       Finance
#
#         Last_Updated   Android_Ver
# ...

# %% [markdown]
# ### Drop Unused Columns
#
# **Challenge**: Remove the columns called `Last_Updated` and `Android_Version` from the DataFrame. We will not use these columns.

# %%
df_apps.drop(labels=['Android_Ver', 'Last_Updated'], axis=1, inplace=True)
df_apps.head()
# Out:
#                                             App         Category  Rating  \
# 0                       Ak Parti Yardım Toplama           SOCIAL     NaN
# 1                    Ain Arabic Kids Alif Ba ta           FAMILY     NaN
# 2  Popsicle Launcher for Android P 9.0 launcher  PERSONALIZATION     NaN
# 3                     Command & Conquer: Rivals           FAMILY     NaN
# 4                                    CX Network         BUSINESS     NaN
#
#    Reviews  Size_MBs Installs  Type   Price Content_Rating           Genres
# 0        0      8.70        0  Paid  $13.99           Teen           Social
# 1        0     33.00        0  Paid   $2.99       Everyone        Education
# 2        0      5.50        0  Paid   $1.49       Everyone  Personalization
# 3        0     19.00        0   NaN       0   Everyone 10+         Strategy
# 4        0     10.00        0  Free       0       Everyone         Business

# %% [markdown]
# ### Find and Remove NaN values in Ratings
#
# **Challenge**: How may rows have a NaN value (not-a-number) in the Ratings column? Create DataFrame called `df_apps_clean` that does not include these rows.

# %%
nan_rows = df_apps[df_apps.Rating.isna()]
nan_rows.shape
# Out:
# (1474, 10)

# %%
df_apps_clean = df_apps.dropna()
df_apps_clean.shape
# Out:
# (9367, 10)

# %% [markdown]
# ### Find and Remove Duplicates
#
# **Challenge**: Are there any duplicates in data? Check for duplicates using the [.duplicated()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html) function. How many entries can you find for the "Instagram" app? Use [.drop_duplicates()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop_duplicates.html) to remove any duplicates from `df_apps_clean`.

# %%
# Check for duplicates
df_apps_clean.duplicated().value_counts()
duplicated_rows = df_apps_clean[df_apps_clean.duplicated()]

print(duplicated_rows.shape)
duplicated_rows.head()
# Out:
# (476, 10)
#                                              App Category  Rating  Reviews  \
# 946                       420 BZ Budeze Delivery  MEDICAL    5.00        2
# 1133                                 MouseMingle   DATING    2.70        3
# 1196  Cardiac diagnosis (heart rate, arrhythmia)  MEDICAL    4.40        8
# 1231                                Sway Medical  MEDICAL    5.00        3
# 1247              Chat Kids - Chat Room For Kids   DATING    4.70        6
#
#       Size_MBs Installs  Type   Price Content_Rating   Genres
# 946      11.00      100  Free       0     Mature 17+  Medical
# 1133      3.90      100  Free       0     Mature 17+   Dating
# 1196      6.50      100  Paid  $12.99       Everyone  Medical
# 1231     22.00      100  Free       0       Everyone  Medical
# 1247      4.90      100  Free       0     Mature 17+   Dating

# %%
# Instagram entries
df_apps_clean[df_apps_clean.App == 'Instagram']
# Out:
#              App Category  Rating   Reviews  Size_MBs       Installs  Type  \
# 10806  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
# 10808  Instagram   SOCIAL    4.50  66577446      5.30  1,000,000,000  Free
# 10809  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
# 10810  Instagram   SOCIAL    4.50  66509917      5.30  1,000,000,000  Free
#
#       Price Content_Rating  Genres
# 10806     0           Teen  Social
# 10808     0           Teen  Social
# 10809     0           Teen  Social
# 10810     0           Teen  Social

# %%
# We need to provide the column names that should be used in the comparison to identify duplicates
# If we do this (drop_duplicates) without specifying how to identify duplicates, we see that 3 copies of Instagram 
# are retained because they have a different number of reviews. We need to provide the column names that should be 
# used in the comparison to identify duplicates.

df_apps_clean.drop_duplicates(inplace=True, subset=['App', 'Type', 'Price'])
df_apps_clean[df_apps_clean.App == 'Instagram']
# Out:
#              App Category  Rating   Reviews  Size_MBs       Installs  Type  \
# 10806  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
#
#       Price Content_Rating  Genres
# 10806     0           Teen  Social

# %%
df_apps_clean.shape
# Out:
# (8199, 10)

# %% [markdown]
# # Find Highest Rated Apps
#
# **Challenge**: Identify which apps are the highest rated. What problem might you encounter if you rely exclusively on ratings alone to determine the quality of an app?

# %%
df_apps_clean.sort_values(by='Rating', ascending=False).head()
# Out:
#                                            App     Category  Rating  Reviews  \
# 21                         KBA-EZ Health Guide      MEDICAL    5.00        4
# 1751                     Spine- The dating app       DATING    5.00        5
# 1761             Selfie With Champion AJ Style  PHOTOGRAPHY    5.00        2
# 1763                     Ag Valley Cooperative     BUSINESS    5.00        6
# 1769  Yazdani Cd Center EllahAbad Official App       FAMILY    5.00        8
#
#       Size_MBs Installs  Type Price Content_Rating         Genres
# 21       25.00        1  Free     0       Everyone        Medical
# 1751      9.30      500  Free     0           Teen         Dating
# 1761      7.50      500  Free     0       Everyone    Photography
# 1763     74.00      500  Free     0       Everyone       Business
# 1769      3.80      500  Free     0       Everyone  Entertainment

# %% [markdown]
# # Find 5 Largest Apps in terms of Size (MBs)
#
# **Challenge**: What's the size in megabytes (MB) of the largest Android apps in the Google Play Store. Based on the data, do you think there could be limit in place or can developers make apps as large as they please?

# %%
df_apps_clean.sort_values(by="Size_MBs", ascending=False).head()
# Out:
#                                      App Category  Rating  Reviews  Size_MBs  \
# 8719          Draft Simulator for FUT 18   SPORTS    4.60   162933    100.00
# 8718   Mini Golf King - Multiplayer Game     GAME    4.50   531458    100.00
# 10295                    SimCity BuildIt   FAMILY    4.50  4218587    100.00
# 9945                     Ultimate Tennis   SPORTS    4.30   183004    100.00
# 9944        Gangster Town: Vice District   FAMILY    4.30    65146    100.00
#
#          Installs  Type Price Content_Rating      Genres
# 8719    5,000,000  Free     0       Everyone      Sports
# 8718    5,000,000  Free     0       Everyone      Sports
# 10295  50,000,000  Free     0   Everyone 10+  Simulation
# 9945   10,000,000  Free     0       Everyone      Sports
# 9944   10,000,000  Free     0     Mature 17+  Simulation

# %% [markdown]
# # Find the 5 App with Most Reviews
#
# **Challenge**: Which apps have the highest number of reviews? Are there any paid apps among the top 50?

# %%
df_apps_clean.sort_values(by='Reviews', ascending=False).head(50)
# Out:
#                                                      App            Category  \
# 10805                                           Facebook              SOCIAL
# 10785                                 WhatsApp Messenger       COMMUNICATION
# 10806                                          Instagram              SOCIAL
# 10784           Messenger – Text and Video Chat for Free       COMMUNICATION
# 10650                                     Clash of Clans                GAME
# 10744            Clean Master- Space Cleaner & Antivirus               TOOLS
# 10835                                     Subway Surfers                GAME
# 10828                                            YouTube       VIDEO_PLAYERS
# 10746  Security Master - Antivirus, VPN, AppLock, Boo...               TOOLS
# 10584                                       Clash Royale                GAME
# 10763                                   Candy Crush Saga                GAME
# ...

# %% [markdown]
# # Plotly Pie and Donut Charts - Visualise Categorical Data: Content Ratings

# %%
# Get all the occurrences of Content Ratings
ratings = df_apps_clean.Content_Rating.value_counts()
ratings
# Out:
# Content_Rating
# Everyone           6621
# Teen                912
# Mature 17+          357
# Everyone 10+        305
# Adults only 18+       3
# Unrated               1
# Name: count, dtype: int64

# %%
# Creating an graph object
fig = express.pie(labels=ratings.index, values=ratings.values, title="Content Rating", names=ratings.index)
fig.update_traces(textposition='outside', textinfo='percent+label')
fig.show()

# %%
# Creating a Donut 🍩🍩
fig = express.pie(labels=ratings.index, values=ratings.values, title="Content Rating", names=ratings.index, hole=0.6)
fig.update_traces(textposition='inside', textfont_size=15, textinfo='percent')
fig.show()

# %% [markdown]
# # Numeric Type Conversion: Examine the Number of Installs
#
# **Challenge**: How many apps had over 1 billion (that's right - BILLION) installations? How many apps just had a single install?
#
# Check the datatype of the Installs column.
#
# Count the number of apps at each level of installations.
#
# Convert the number of installations (the Installs column) to a numeric data type. Hint: this is a 2-step process. You'll have make sure you remove non-numeric characters first.

# %%
# How many apps had over 1 billion (that's right - BILLION) installations? 
# How many apps just had a single install?

installations = df_apps_clean.groupby('Installs').count()
installations[installations.index == "1,000,000,000"]
installations[installations.index == "1"]

# To check the data types you can either use .describe() on the column or .info() on the DataFrame.
df_apps_clean.info()
df_apps_clean.Installs.describe()
# Out:
# <class 'pandas.DataFrame'>
# Index: 8199 entries, 21 to 10835
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             8199 non-null   str
#  1   Category        8199 non-null   str
#  2   Rating          8199 non-null   float64
#  3   Reviews         8199 non-null   int64
#  4   Size_MBs        8199 non-null   float64
#  5   Installs        8199 non-null   str
#  6   Type            8199 non-null   str
#  7   Price           8199 non-null   str
#  8   Content_Rating  8199 non-null   str
#  9   Genres          8199 non-null   str
# dtypes: float64(2), int64(1), str(7)
# memory usage: 704.6 KB
# count          8199
# unique           19
# top       1,000,000
# freq           1417
# Name: Installs, dtype: object

# %%
# Check the datatype of the Installs column.
type(installations.index[0])
# Out:
# str

# %%
# Count the number of apps at each level of installations.
installations

# If we take two of the columns, say Installs and the App name, we can count the number of entries per 
# level of installations with .groupby() and .count()
df_apps_clean[['App', 'Installs']].groupby('Installs').count()
# Out:
#                 App
# Installs
# 1                 3
# 1,000           698
# 1,000,000      1417
# 1,000,000,000    20
# 10               69
# 10,000          988
# 10,000,000      933
# 100             303
# 100,000        1096
# 100,000,000     189
# 5                 9
# 5,000           425
# 5,000,000       607
# 50               56
# 50,000          457
# 50,000,000      202
# 500             199
# 500,000         504
# 500,000,000      24

# %%
# Convert the number of installations (the Installs column) to a numeric data type. 
# Hint: this is a 2-step process. You'll have to make sure you remove non-numeric characters first.
installations
df_apps_clean.Installs = df_apps_clean.Installs.astype(str).str.replace(',', "")
df_apps_clean.Installs = pandas.to_numeric(df_apps_clean.Installs)
df_apps_clean[['App', 'Installs']].groupby('Installs').count()
# Out:
#              App
# Installs
# 1              3
# 5              9
# 10            69
# 50            56
# 100          303
# 500          199
# 1000         698
# 5000         425
# 10000        988
# 50000        457
# 100000      1096
# 500000       504
# 1000000     1417
# 5000000      607
# 10000000     933
# 50000000     202
# 100000000    189
# 500000000     24
# 1000000000    20

# %% [markdown]
# # Find the Most Expensive Apps, Filter out the Junk, and Calculate a (ballpark) Sales Revenue Estimate
#
# Let's examine the Price column more closely.
#
# **Challenge**: Convert the price column to numeric data. Then investigate the top 20 most expensive apps in the dataset.
#
# Remove all apps that cost more than $250 from the `df_apps_clean` DataFrame.
#
# Add a column called 'Revenue_Estimate' to the DataFrame. This column should hold the price of the app times the number of installs. What are the top 10 highest grossing paid apps according to this estimate? Out of the top 10 highest grossing paid apps, how many are games?

# %%
# Convert the price column to numeric data. Then investigate the top 20 most expensive apps in the dataset.
df_apps_clean.Price = df_apps_clean.Price.astype(str).str.replace('$', '')
df_apps_clean.Price = pandas.to_numeric(df_apps_clean.Price)
df_apps_clean.sort_values(by='Price', ascending=False).head(20)
# Out:
#                                  App   Category  Rating  Reviews  Size_MBs  \
# 3946        I'm Rich - Trump Edition  LIFESTYLE    3.60      275      7.30
# 2394                      I am Rich!    FINANCE    3.80       93     22.00
# 2461              I AM RICH PRO PLUS    FINANCE    4.00       36     41.00
# 1331          most expensive app (H)     FAMILY    4.30        6      1.50
# 3145              I am rich(premium)    FINANCE    3.50      472      0.94
# 2775                   I Am Rich Pro     FAMILY    4.40      201      2.70
# 5765                       I am rich  LIFESTYLE    3.80     3547      1.80
# 3221                  I am Rich Plus     FAMILY    4.00      856      8.70
# 3554                      💎 I'm rich  LIFESTYLE    3.80      718     26.00
# 3114                       I am Rich    FINANCE    4.30      180      3.80
# 4606               I Am Rich Premium    FINANCE    4.10     1867      4.70
# ...

# %% [markdown]
# ### The most expensive apps sub $250

# %%
# Remove all apps that cost more than $250 from the df_apps_clean DataFrame.
df_apps_clean[df_apps_clean.Price > 250].value_counts()
df_apps_clean = df_apps_clean.drop(df_apps_clean[df_apps_clean['Price'] > 250].index)
df_apps_clean.sort_values(by='Price', ascending=False).head()

# or....
# df_apps_clean = df_apps_clean[df_apps_clean.Price < 250]
# Out:
#                             App   Category  Rating  Reviews  Size_MBs  \
# 2281  Vargo Anesthesia Mega App    MEDICAL    4.60       92     32.00
# 1407               LTC AS Legal    MEDICAL    4.00        6      1.30
# 2629           I am Rich Person  LIFESTYLE    4.20      134      1.80
# 2481    A Manual of Acupuncture    MEDICAL    3.50      214     68.00
# 504   AP Art History Flashcards     FAMILY    5.00        1     96.00
#
#       Installs  Type  Price Content_Rating     Genres
# 2281      1000  Paid  79.99       Everyone    Medical
# 1407       100  Paid  39.99       Everyone    Medical
# 2629      1000  Paid  37.99       Everyone  Lifestyle
# 2481      1000  Paid  33.99       Everyone    Medical
# 504         10  Paid  29.99     Mature 17+  Education

# %% [markdown]
# ### Highest Grossing Paid Apps (ballpark estimate)

# %%
# Add a column called 'Revenue_Estimate' to the DataFrame. This column should hold the price of the app 
# times the number of installs. What are the top 10 highest-grossing paid apps according to this 
# estimate? Out of the top 10, how many are games?

df_apps_clean['Revenue_Estimate'] = df_apps_clean.Installs.mul(df_apps_clean.Price)
df_apps_clean.sort_values(by='Revenue_Estimate', ascending=False)[:10]
# Out:
#                                 App     Category  Rating  Reviews  Size_MBs  \
# 9220                      Minecraft       FAMILY    4.50  2376564     19.00
# 8825                  Hitman Sniper         GAME    4.60   408292     29.00
# 7151  Grand Theft Auto: San Andreas         GAME    4.40   348962     26.00
# 7477            Facetune - For Free  PHOTOGRAPHY    4.40    49553     48.00
# 7977        Sleep as Android Unlock    LIFESTYLE    4.50    23966      0.85
# 6594            DraStic DS Emulator         GAME    4.60    87766     12.00
# 6082                   Weather Live      WEATHER    4.50    76593      4.75
# 6746     Card Wars - Adventure Time       FAMILY    4.30   129603     23.00
# 7633        Five Nights at Freddy's         GAME    4.60   100805     50.00
# 7954                    Bloons TD 5       FAMILY    4.60   190086     94.00
#
#       Installs  Type  Price Content_Rating                     Genres  \
# ...

# %% [markdown]
# # Plotly Bar Charts & Scatter Plots: Analysing App Categories

# %%
# We can find the number of different categories like so:
print(df_apps_clean.Category.nunique())
# Out:
# 33

# %%
# To calculate the number of apps per category we can use our old friend .value_counts()
top_10_apps = df_apps_clean.Category.value_counts()[:10]
top_10_apps
# Out:
# Category
# FAMILY             1606
# GAME                910
# TOOLS               719
# PRODUCTIVITY        301
# PERSONALIZATION     298
# LIFESTYLE           297
# FINANCE             296
# MEDICAL             292
# PHOTOGRAPHY         263
# BUSINESS            262
# Name: count, dtype: int64

# %% [markdown]
# ### Vertical Bar Chart - Highest Competition (Number of Apps)

# %%
# To visualise this data in a bar chart we can use the plotly express (our px) bar() function:
bar = express.bar(x=top_10_apps.index, y=top_10_apps.values)
bar.show()

# %% [markdown]
# ### Horizontal Bar Chart - Most Popular Categories (Highest Downloads)

# %%
# But what if we look at it from a different perspective? What matters is not just the 
# total number of apps in the category but how often apps are downloaded in that category. 
# This will give us an idea of how popular a category is. First, we have to group all our 
# apps by category and sum the number of installations:

category_installs = df_apps_clean.groupby(by='Category').agg({'Installs': pandas.Series.sum})
category_installs.sort_values(by='Installs', ascending=True, inplace=True)
category_installs.head()
# Out:
#            Installs
# Category
# EVENTS     15949410
# BEAUTY     26916200
# PARENTING  31116110
# MEDICAL    39162676
# COMICS     44931100

# %%
horizontal_bar = express.bar(x=category_installs.Installs, y=category_installs.index, orientation='h', title='Category Popularity')
horizontal_bar.update_layout(xaxis_title='Number of Downloads', yaxis_title='Category')
horizontal_bar.show()

# %% [markdown]
# ### Category Concentration - Downloads vs. Competition
#
# **Challenge**:
# * First, create a DataFrame that has the number of apps in one column and the number of installs in another:
#
# <img src=https://imgur.com/uQRSlXi.png width="350">
#
# * Then use the [plotly express examples from the documentation](https://plotly.com/python/line-and-scatter/) alongside the [.scatter() API reference](https://plotly.com/python-api-reference/generated/plotly.express.scatter.html)to create scatter plot that looks like this.
#
# <img src=https://imgur.com/cHsqh6a.png>
#
# *Hint*: Use the size, hover_name and color parameters in .scatter(). To scale the yaxis, call .update_layout() and specify that the yaxis should be on a log-scale like so: yaxis=dict(type='log')

# %%
# Create a DataFrame that has the number of apps in one column and the number of installs in another:
app_installs = df_apps_clean.groupby(by='Category').agg({'App': pandas.Series.count, 'Installs': pandas.Series.sum})
app_installs.sort_values(by='Installs', ascending=False, inplace=True)
app_installs.head()
# app_installs.shape
# Out:
#                App     Installs
# Category
# GAME           910  13858762717
# COMMUNICATION  257  11039241530
# TOOLS          719   8099724500
# PRODUCTIVITY   301   5788070180
# SOCIAL         203   5487841475

# %%
# Another way to solve the code above:
# First, we need to work out the number of apps in each category (similar to what we did previously).
# cat_number = df_apps_clean.groupby('Category').agg({'App': pd.Series.count})
# 
# Then we can use .merge() and combine the two DataFrames.
# cat_merged_df = pd.merge(cat_number, category_installs, on='Category', how="inner")
# print(f'The dimensions of the DataFrame are: {cat_merged_df.shape}')
# cat_merged_df.sort_values('Installs', ascending=False)

# %%
# Then use the plotly express examples from the documentation alongside the .scatter() 
# API reference to create scatter plot that looks like the chart above.

sc = express.scatter(data_frame=app_installs, x=app_installs.App, y=app_installs.Installs, title='Category Concentration', color='Installs', size='App', hover_name=app_installs.index )
sc.update_layout(xaxis_title="Number of Apps (Lower=More Concentrated)", yaxis=dict(type='log'))
sc.show()

# %% [markdown]
# # Extracting Nested Data from a Column
#
# **Challenge**: How many different types of genres are there? Can an app belong to more than one genre? Check what happens when you use .value_counts() on a column with nested values? See if you can work around this problem by using the .split() function and the DataFrame's [.stack() method](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.stack.html).

# %%
# How many different types of genres are there?
len(df_apps_clean.Genres.unique())

# Can an app belong to more than one genre? 
# Check what happens when you use .value_counts() on a column with nested values?
df_apps_clean.Genres.value_counts().sort_values(ascending=True)[:5]
# Out:
# Genres
# Adventure;Education                  1
# Lifestyle;Pretend Play               1
# Travel & Local;Action & Adventure    1
# Art & Design;Pretend Play            1
# Communication;Creativity             1
# Name: count, dtype: int64

# %%
# We somehow need to separate the genre names to get a clear picture. 
# This is where the string’s .split() method comes in handy. 
# After we’ve separated our genre names based on the semi-colon, 
# we can add them all into a single column with .stack() and then use .value_counts().

stack = df_apps_clean.Genres.str.split(';', expand=True).stack()
print(f"single column with genres: \n{stack}")
print(f"shape: \n{stack.shape}")
num_genres = stack.value_counts()
print(f"length of stack: {len(num_genres)}")
# Out:
# single column with genres:
# 21     0             Medical
#        1                 NaN
# 28     0              Arcade
#        1                 NaN
# 47     0              Arcade
#                   ...
# 10829  1                 NaN
# 10831  0    News & Magazines
#        1                 NaN
# 10835  0              Arcade
#        1                 NaN
# Length: 16368, dtype: str
# shape:
# (16368,)
# length of stack: 53

# %% [markdown]
# # Colour Scales in Plotly Charts - Competition in Genres

# %% [markdown]
# **Challenge**: Can you create this chart with the Series containing the genre data?
#
# <img src=https://imgur.com/DbcoQli.png width=400>
#
# Try experimenting with the built in colour scales in Plotly. You can find a full list [here](https://plotly.com/python/builtin-colorscales/).
#
# * Find a way to set the colour scale using the color_continuous_scale parameter.
# * Find a way to make the color axis disappear by using coloraxis_showscale.

# %%
# bar = express.bar(x=top_10_apps.index, y=top_10_apps.values)
bar = express.bar(x=num_genres.index[:15], y=num_genres.values[:15],  
                title='Top Genres',
                hover_name=num_genres.index[:15],
                color=num_genres.values[:15],
                color_continuous_scale='Agsunset' )
bar.update_layout(xaxis_title='Genres', yaxis_title='Number of Apps', coloraxis_showscale=False)
bar.show()

# %% [markdown]
# # Grouped Bar Charts: Free vs. Paid Apps per Category

# %%
# Now that we’ve looked at the total number of apps per category and the total 
# number of apps per genre, let’s see what the split is between free and paid apps.

df_apps_clean.Type.value_counts()
# Out:
# Type
# Free    7595
# Paid     589
# Name: count, dtype: int64

# %%
# We see that the majority of apps are free on the Google Play Store. 
# But perhaps some categories have more paid apps than others. 
# Let’s investigate. We can group our data first by Category and then by Type. 
# Then we can add up the number of apps per each type. Using as_index=False 
# we push all the data into columns rather than end up with our Categories as the index.

df_free_vs_paid = df_apps_clean.groupby(['Category', 'Type'], as_index=False).agg({'App':pandas.Series.count})
df_free_vs_paid.head()
# Out:
#             Category  Type  App
# 0     ART_AND_DESIGN  Free   58
# 1     ART_AND_DESIGN  Paid    3
# 2  AUTO_AND_VEHICLES  Free   72
# 3  AUTO_AND_VEHICLES  Paid    1
# 4             BEAUTY  Free   42

# %% [markdown]
# **Challenge**: Use the plotly express bar [chart examples](https://plotly.com/python/bar-charts/#bar-chart-with-sorted-or-ordered-categories) and the [.bar() API reference](https://plotly.com/python-api-reference/generated/plotly.express.bar.html#plotly.express.bar) to create this bar chart:
#
# <img src=https://imgur.com/LE0XCxA.png>
#
# You'll want to use the `df_free_vs_paid` DataFrame that you created above that has the total number of free and paid apps per category.
#
# See if you can figure out how to get the look above by changing the `categoryorder` to 'total descending' as outlined in the documentation here [here](https://plotly.com/python/categorical-axes/#automatically-sorting-categories-by-name-or-total-value).

# %%
bar = express.bar(df_free_vs_paid,
                  x=df_free_vs_paid.Category, 
                  y=df_free_vs_paid.App,
                  title='Free vs Paid Apps by Category',
                  color='Type',
                  barmode='group')
bar.update_layout(xaxis_title='Category',
                  yaxis_title='Number of Apps',
                  xaxis={'categoryorder':'total descending'},
                  yaxis=dict(type='log'))

bar.add_trace(graph_objects.Bar(
    x=df_free_vs_paid.Category,
    y=df_free_vs_paid[df_free_vs_paid.App == 'Free'],
    name='Type=Free',
    marker_color='indianred'
))
bar.add_trace(graph_objects.Bar(
    x=df_free_vs_paid.Category,
    y=df_free_vs_paid[df_free_vs_paid.App == 'Paid'],
    name='Type=Paid',
    marker_color='lightsalmon'
))

bar.update_xaxes(categoryorder='total descending')
bar.show()

# %% [markdown]
# # Plotly Box Plots: Lost Downloads for Paid Apps
#
# **Challenge**: Create a box plot that shows the number of Installs for free versus paid apps. How does the median number of installations compare? Is the difference large or small?
#
# Use the [Box Plots Guide](https://plotly.com/python/box-plots/) and the [.box API reference](https://plotly.com/python-api-reference/generated/plotly.express.box.html) to create the following chart.
#
# <img src=https://imgur.com/uVsECT3.png>

# %%
# df_free_vs_paid = df_apps_clean.groupby(['Category', 'Type'], as_index=False).agg({'App':pandas.Series.count})
box = express.box(df_apps_clean,
             y='Installs',
             x='Type',
             color='Type',
             notched=True,
             points='all',
             title='How Many Downloads are Paid Apps Giving Up?')
 
box.update_layout(yaxis=dict(type='log'))
 
box.show()

# %% [markdown]
# # Plotly Box Plots: Revenue by App Category
#
# **Challenge**: See if you can generate the chart below:
#
# <img src=https://imgur.com/v4CiNqX.png>
#
# Looking at the hover text, how much does the median app earn in the Tools category? If developing an Android app costs $30,000 or thereabouts, does the average photography app recoup its development costs?
#
# Hint: I've used 'min ascending' to sort the categories.

# %%
df_paid_apps = df_apps_clean[df_apps_clean['Type'] == 'Paid']
box = express.box(df_paid_apps, 
             x='Category', 
             y='Revenue_Estimate',
             title='How Much Can Paid Apps Earn?')
 
box.update_layout(xaxis_title='Category',
                  yaxis_title='Paid App Ballpark Revenue',
                  xaxis={'categoryorder':'min ascending'},
                  yaxis=dict(type='log'))
 
 
box.show()

# %% [markdown]
# # How Much Can You Charge? Examine Paid App Pricing Strategies by Category
#
# **Challenge**: What is the median price price for a paid app? Then compare pricing by category by creating another box plot. But this time examine the prices (instead of the revenue estimates) of the paid apps. I recommend using `{categoryorder':'max descending'}` to sort the categories.

# %%
box = express.box(df_paid_apps,
             x='Category',
             y="Price",
             title='Price per Category')
 
box.update_layout(xaxis_title='Category',
                  yaxis_title='Paid App Price',
                  xaxis={'categoryorder':'max descending'},
                  yaxis=dict(type='log'))
 
box.show()
